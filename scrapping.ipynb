# %%
#!pip install requests beautifulsoup4

# %%
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import json
import os
output_root_dir='ifc_raw'
def get_substring_from_string(pattern,  text, default=None):
    match = re.search(pattern, text)
    if match:
        return(match.group(1))
    else:
        print("warning Pattern not found, returning default")
        return(default)

def get_soup(url):
    response = requests.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')
    return(soup)

def get_url_section_item_list(url,soup):
    lst=[]
    for link in soup.find_all("a"):
        href = link.get("href")
        if href and 'lexical' in href and not href.startswith("#"):
            full_url = urljoin(url, href)
            lst.append(full_url)
    return(lst)

def get_output_file_name(section,title, sub_title_pattern=r'\b(Ifc\w+)\b'):
    file_name=get_substring_from_string(sub_title_pattern, title)   
    version=get_substring_from_string("\s(IFC\d+(\.\d+)*)\s", title, default='IFC4.3.2.0').replace(".", "_")
    output_dir=f'{output_root_dir}/{version}/{section}'
    full_file_path=f'{output_dir}/{file_name}'
    return(full_file_path)
def get_file_sections_as_dict(item_soup):
    doc_dct={}
    headers = item_soup.find_all('h2')
    for header in headers:
        normalized_header_text = header_text = re.sub(r'\d+(\.\d+)*\s*', '', header.get_text()).strip().replace(" ", "_").lower()
        content = []
        sibling = header.find_next_sibling()
        while sibling and sibling.name != 'h2' and sibling.name !="aside":
                    content.append(sibling.get_text())
                    sibling = sibling.find_next_sibling()
        # Store the content in the dictionary
        doc_dct[normalized_header_text] = content 
    return(doc_dct)
def write_to_json(data, filename):
    with open(f'{filename}.json', 'w') as f:
        json.dump(data, f)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

root_glossary=[
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b1.html', passed
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b2.html, passed
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b3.html', passes
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b4.html', passed
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b5.html',passed
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b6.html',passed
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b7.html' passed
  ]

for url in root_glossary:
    print(url)
    soup=get_soup(url=url)
    title = soup.title.get_text()
    print(title)
    section=get_substring_from_string(r"\s-\s([\w+\s]+)\s-\sIFC", title).lower().replace(" ", "_")
    url_section_item_list=get_url_section_item_list(url, soup)
    for item_url in url_section_item_list:
        print(f"{item_url} before get soup")
        item_soup=get_soup(item_url)
        headers = item_soup.find_all('h2')
        title = item_soup.title.get_text()
        sub_title_pattern=r'\b(Ifc\w+)\b'
        if("Pset_" in title):
            sub_title_pattern=r'\b(Pset_\w+)\b'
        if("Qto_" in title):
            sub_title_pattern=r'\b(Qto_\w+)\b'
        if("PEnum_" in title):
            sub_title_pattern=r'\b(PEnum_\w+)\b'
        output_file_name=get_output_file_name(section,title, sub_title_pattern=sub_title_pattern)
        file_dct=get_file_sections_as_dict( item_soup)
        if not os.path.exists(os.path.dirname(output_file_name)):
            os.makedirs(os.path.dirname(output_file_name))
        write_to_json(file_dct,output_file_name)
# Out:
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b7.html
# Annex B
# (informative)
#
# Alphabetical listings - Property Enumerations - IFC4.3.2.0 Documentation
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AccidentResponse.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AcquisitionMethod.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ActuatorApplication.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AddedMassCoefficientMethod.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AdditionalProcessing.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AddressType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AddressabilityType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AdjustmentValueType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirHandlerConstruction.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirHandlerFanCoilArrangement.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirSideSystemDistributionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirSideSystemType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalAirFlowType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalBoxArrangementType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalBoxReheatType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalCoreType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalDischargeDirection.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalFaceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalFinishType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalFlowControlType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalFlowPattern.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalLocation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalMountingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirTerminalShape.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AirToAirHeatTransferHeatTransferType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AnchorageType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AntennaType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ArrangerPositionEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AssemblyPlace.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AssetAccountingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AssetInsuranceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AssetRating.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AssetTaxType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AudioVisualAmplifierType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AudioVisualCameraType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AudioVisualDisplayTouchScreen.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AudioVisualDisplayType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AudioVisualPlayerType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AudioVisualProjectorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AudioVisualReceiverType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AudioVisualSpeakerMounting.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AudioVisualSpeakerType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AudioVisualTunerType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_AxleCountingEquipmentType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BackInletPatternType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BackflowPreventerType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BackupSupplySystemType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BathType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BatteryChargingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BerthApproach.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BerthMode.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BladesOrientation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BoilerOperatingMode.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BoreholeState.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BranchLineDirection.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BreechingInletCouplingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BreechingInletType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BuildingThermalExposure.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_BumperOrientation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CableArmourType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CableFunctionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CantileverAssemblyType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CatenaryStayType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CentrifugalFanArrangement.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CentrifugalFanDischargePosition.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CentrifugalFanRotation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CheckRailType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CisternHeight.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CoilConnectionDirection.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CoilCoolant.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CoilFluidArrangement.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CoilPlacementType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CommonInterfaceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CommunicationStandard.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ComplementaryWorks.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CompressedAirFilterType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CompressorTypePowerSource.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ComputerUIType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ConcreteCastingMethod.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ConductorFunctionEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ConduitShapeType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ConstructionEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ContactorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ControlDamperOperation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ControllerApplication.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ControllerInterfaceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ControllerMultiPositionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ControllerProportionalType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ControllerTwoPositionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ControllerTypeFloating.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ControllerTypeProgrammable.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CooledBeamActiveAirFlowConfigurationType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CooledBeamIntegratedLightingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CooledBeamPipeConnection.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CooledBeamSupplyAirConnectionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CooledBeamWaterFlowControlSystemType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CoolingTowerCapacityControl.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CoolingTowerCircuitType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CoolingTowerControlStrategy.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CoolingTowerFlowArrangement.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CoolingTowerSprayType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CoreColoursEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_CurveShapeEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DamperBladeAction.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DamperBladeEdge.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DamperBladeShape.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DamperOperation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DamperOrientation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DamperSizingMethod.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DataCollectionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DataConnectionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DataTransmissionUnitUsage.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DispatchingBoardType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DistributionPortElectricalType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DistributionPortGender.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DistributionSystemElectricalCategory.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DistributionSystemElectricalType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DoorPanelOperationEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DoorPanelPositionEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DrillOnRail.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DuctConnectionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DuctSegmentShape.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_DuctSizingMethod.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_EarthFailureDeviceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_EarthquakeSensorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElectricActuatorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElectricApplianceDishwasherType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElectricApplianceElectricCookerType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElectricalFeederType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElectrificationType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElectroMagneticTrippingUnitType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElectronicFilterType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElectronicTrippingUnitType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElementComponentCorrosionTreatment.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElementComponentDeliveryType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElementShading.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ElementStatus.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_EndShapeType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_EnergySource.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_EngineEnergySource.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_EvaporativeCoolerFlowArrangement.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_EvaporatorCoolant.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_EvaporatorMediumType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ExpansionDirection.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FailPosition.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FanApplicationType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FanCapacityControlType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FanCoilPosition.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FanDischargeType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FanMotorConnectionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FanMotorPosition.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FanMountingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FaucetFunction.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FaucetOperation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FaucetType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FenderType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FiberColour.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FiberMode.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FiberType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FilterAirParticleFilterSeparationType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FilterAirParticleFilterType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FilterWaterFilterType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FireDamperActuationType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FireDamperClosureRating.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FireHydrantType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FittingJunctionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FlowMeterPurpose.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FlushType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ForeignObjectDetectionSensorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FountainType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FunctionEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FurniturePanelType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_FuseDisconnectorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_GasType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_GuardRailConnection.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_GuardRailType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_GullyType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_HeatExchangerArrangement.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_HeatTransferMedium.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_HoseNozzleType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_HoseReelMountingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_HoseReelType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_HumidifierApplication.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_HumidifierInternalControl.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ImageShootingMode.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_InletPatternType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_InputOutputSignalType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_InstallationMethodFlagEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_InstalledCondition.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_InsulationStandardClass.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_InsulatorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_IsolatingPurpose.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_JointRelativePosition.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_JunctionBoxMountingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_JunctionBoxPlacingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_JunctionBoxShapeType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LRMType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LampBallastType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LampCompensationType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LifeCyclePhase.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LightFixtureMountingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LightFixturePlacingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LightFixtureSecurityLightingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LineCharacteristic.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LoadDisconnectionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LubricationPowerSupply.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_LubricationSystemType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MaintenanceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MarkerType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MasterUnitType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MaterialEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MechanicalStressType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MeterReadOutType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MixingValveControl.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ModemTrafficInterfaceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MonitoringType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MooringDeviceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MotorEnclosureType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MountingMethodEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_MovementSensingType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_OCSFasteningType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_OpticalCableStructureType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_OpticalNetworkUnitType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_OpticalSplitterType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_OverheadContactLineType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PackingCareType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PaymentMethod.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PermeableCoveringOperationEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PictogramEscapeDirectionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PipeEndStyleTreatment.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PolarizationMode.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PoleUsage.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PowerSupplyMode.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PressureGaugeType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PriorityType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ProcessDirection.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ProcessItem.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ProjectType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PropertyAgreementType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PumpBaseType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_PumpDriveConnectionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RadiationPattern.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RailCondition.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RailDeliveryState.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RailElementaryLength.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RailPadStiffness.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RailwayBaliseType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RailwayCommunicationTerminalType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RailwaySignalType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RainSensorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RefrigerantClass.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ReinforcementBarAllocationType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ReinforcementBarType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RelativePosition.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RiskRating.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_RiskType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SanitaryMounting.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SecondaryCurrentType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SectionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SectioningDeviceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SelfTestType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SerialInterfaceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ShapeEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ShowerType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SideType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SignalIndicatorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SinkType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SleeperArrangement.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SleeperType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SnowSensorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SoilCompositeFractions.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SoundScale.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SpaceHeaterConvectorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SpaceHeaterHeatTransferDimension.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SpaceHeaterPlacementType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SpaceHeaterRadiatorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SpaceHeaterTemperatureClassification.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SparkGapType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SprinklerActivation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SprinklerBulbLiquidColour.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SprinklerResponse.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SprinklerType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_StarterType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SteadyDeviceType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_StrataAssemblyPurpose.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_StructureIndicator.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SupportingSystemType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SwitchActivation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SwitchDisconnectorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SwitchFunctionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SwitchUsage.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SwitchingDeviceDimmerSwitchType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SwitchingDeviceEmergencyStopType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SwitchingDeviceKeypadType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SwitchingDeviceMomentarySwitchType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_SwitchingDeviceToggleSwitchType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TankAccessType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TankComposition.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TankPatternType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TankStorageType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TemperatureSensorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ThermalTrippingUnitType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ThermometerType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TicketVendingMachineType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ToiletPanType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ToiletType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ToleranceBasis.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TrackCharacteristic.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TrackFasteningElasticityType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TrackSupportingStructure.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TrackUsage.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TrainCategory.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TransformerVectorGroup.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TransitionSuperelevationType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TransitionWidthType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TransmissionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TransmittedSignal.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TransportEquipmentAssemblyType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TransportEquipmentType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TrapType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TrippingCurveType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TrippingUnitReleaseCurrent.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TurnoutHeaterType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TurnoutPanelOrientation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TurnstileType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TypeOfCurvedTurnout.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TypeOfDrivingDevice.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TypeOfJunction.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TypeOfShaft.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_TypeOfTurnout.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_UncertaintyBasis.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_UnderSleeperPadStiffness.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_UnitConnectionType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_UnitaryControlElementApplication.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_UrinalType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_UsagePurpose.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ValveMechanism.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ValveOperation.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_ValvePattern.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_VaristorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_VendingMachineUserInterface.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_VoltageLevels.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_WashHandBasinType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_WaterMeterType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_WindSensorType.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_WindowPanelOperationEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_WindowPanelPositionEnum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/PEnum_WirePairType.htm before get soup

# %%
section,title
# Out:
# ('property_enumerations',
#  '7.8.8.48 PEnum_PowerSupplyMode - IFC4.3.2.0 Documentation')

# %%
get_substring_from_string(r'\b(PEnum_\w+)\b', '7.8.8.48 PEnum_PowerSupplyMode - IFC4.3.2.0 Documentation')
# Out:
# 'PEnum_PowerSupplyMode'

# %%
import json
with open('/Users/amit/github/ifc_raw/IFC4_3_2_0/entities/IfcMaterialLayer.json') as json_file:
    data = json.load(json_file)
data.keys()

# %%
data['semantic_definition']

# %%
data['attributes']

# %%
data['formal_propositions']

# %%
data['formal_representation']

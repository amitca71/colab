# %%
#!pip install requests beautifulsoup4

# %%
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import json
import os
output_root_dir='ifc_raw'
def get_substring_from_string(pattern,  text, default=None):
    match = re.search(pattern, text)
    if match:
        return(match.group(1))
    else:
        print("warning Pattern not found, returning default")
        return(default)

def get_soup(url):
    response = requests.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')
    return(soup)

def get_url_section_item_list(url,soup):
    lst=[]
    for link in soup.find_all("a"):
        href = link.get("href")
        if href and 'lexical' in href and not href.startswith("#"):
            full_url = urljoin(url, href)
            lst.append(full_url)
    return(lst)

def get_output_file_name(section,title):
    file_name=get_substring_from_string(r'\b(Ifc\w+)\b', title)   
    version=get_substring_from_string("\s(IFC\d+(\.\d+)*)\s", title, default='IFC4.3.2.0').replace(".", "_")
    output_dir=f'{output_root_dir}/{version}/{section}'
    full_file_path=f'{output_dir}/{file_name}'
    return(full_file_path)
def get_file_sections_as_dict(item_soup):
    doc_dct={}
    headers = item_soup.find_all('h2')
    for header in headers:
        normalized_header_text = header_text = re.sub(r'\d+(\.\d+)*\s*', '', header.get_text()).strip().replace(" ", "_").lower()
        content = []
        sibling = header.find_next_sibling()
        while sibling and sibling.name != 'h2' and sibling.name !="aside":
                    content.append(sibling.get_text())
                    sibling = sibling.find_next_sibling()
        # Store the content in the dictionary
        doc_dct[normalized_header_text] = content 
    return(doc_dct)
def write_to_json(data, filename):
    with open(f'{filename}.json', 'w') as f:
        json.dump(data, f)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

root_glossary=[
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b1.html', passed
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b2.html, passed
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b3.html', - was errored
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b4.html', passed
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b5.html',passed
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b6.html',passed
# 'https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b7.html' - error 
  ]

for url in root_glossary:
    print(url)
    soup=get_soup(url=url)
    title = soup.title.get_text()
    print(title)
    section=get_substring_from_string(r"\s-\s(\w+)\s-\sIFC", title).lower()
    url_section_item_list=get_url_section_item_list(url, soup)
    for item_url in url_section_item_list:
        print(f"{item_url} before get soup")
        item_soup=get_soup(item_url)
        headers = item_soup.find_all('h2')
        title = item_soup.title.get_text()
        output_file_name=get_output_file_name(section,title)
        file_dct=get_file_sections_as_dict( item_soup)
        if not os.path.exists(os.path.dirname(output_file_name)):
            os.makedirs(os.path.dirname(output_file_name))
        write_to_json(file_dct,output_file_name)
# Out:
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b4.html
# Annex B
# (informative)
#
# Alphabetical listings - Properties - IFC4.3.2.0 Documentation
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b5.html
# Annex B
# (informative)
#
# Alphabetical listings - Functions - IFC4.3.2.0 Documentation
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcAssociatedSurface.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcBaseAxis.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcBooleanChoose.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcBuild2Axes.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcBuildAxes.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcConsecutiveSegments.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcConstraintsParamBSpline.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcConvertDirectionInto2D.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcCorrectDimensions.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcCorrectFillAreaStyle.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcCorrectLocalPlacement.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcCorrectUnitAssignment.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcCrossProduct.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcCurveDim.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcCurveWeightsPositive.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcDeriveDimensionalExponents.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcDimensionsForSIUnit.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcDotProduct.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcFirstProjAxis.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcGetBasisSurface.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcListToArray.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcLoopHeadToTail.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcMakeArrayOfArray.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcMlsTotalThickness.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcNormalise.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcOrthogonalComplement.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcPathHeadToTail.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcPointDim.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcPointListDim.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcSameAxis2Placement.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcSameCartesianPoint.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcSameDirection.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcSameValidPrecision.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcSameValue.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcScalarTimesVector.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcSecondProjAxis.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcSegmentDim.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcShapeRepresentationTypes.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcSurfaceWeightsPositive.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcTaperedSweptAreaProfiles.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcTopologyRepresentationTypes.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcUniqueDefinitionNames.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcUniquePropertyName.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcUniquePropertySetNames.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcUniquePropertyTemplateNames.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcUniqueQuantityNames.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcVectorDifference.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcVectorSum.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b6.html
# Annex B
# (informative)
#
# Alphabetical listings - Rules - IFC4.3.2.0 Documentation
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcRepresentationContextSameWCS.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/lexical/IfcSingleProjectInstance.htm before get soup
# https://standards.buildingsmart.org/IFC/RELEASE/IFC4_3/HTML/annex-b7.html
# Annex B
# (informative)
#
# Alphabetical listings - Property Enumerations - IFC4.3.2.0 Documentation
# warning Pattern not found, returning default
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 20
#      18 title = soup.title.get_text()
#      19 print(title)
# ---> 20 section=get_substring_from_string(r"\s-\s(\w+)\s-\sIFC", title).lower()
#      21 url_section_item_list=get_url_section_item_list(url, soup)
#      22 for item_url in url_section_item_list:
#
# AttributeError: 'NoneType' object has no attribute 'lower'
